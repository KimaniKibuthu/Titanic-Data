# %% [markdown]
# <a href="https://colab.research.google.com/github/KimaniKibuthu/Titanic-Data/blob/master/Titanic_Case.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Titanic Dataset
# Predict whether someone survives the titanic or not.
#
# The process that we will take will be:
#
# 1. Data obtainance.
# 2. Data wrangling.
# 3. Data Visualization.
# 4. Feature Engineering.
# 5. Modelling.
# 6. Deployment

# %% [markdown]
# # Data Obtainance
#
# Here we will obtain our data

# %%
# Importing the necessary libraries
import pandas as pd

# %%
# Load our data
titanic_df = pd.read_csv('/content/train.csv')

# %%
# View our data
titanic_df.sample(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 432          433         1       2
# 214          215         0       3
# 245          246         0       1
# 419          420         0       3
# 153          154         0       3
# 435          436         1       1
# 196          197         0       3
# 687          688         0       3
# 841          842         0       2
# 534          535         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 432  Louch, Mrs. Charles Alexander (Alice Adelaide ...  female  42.0      1
# 214                                Kiernan, Mr. Philip    male   NaN      1
# 245                        Minahan, Dr. William Edward    male  44.0      2
# 419                          Van Impe, Miss. Catharina  female  10.0      0
# 153                    van Billiard, Mr. Austin Blyler    male  40.5      0
# 435                          Carter, Miss. Lucile Polk  female  14.0      1
# ...

# %% [markdown]
# # Data Wrangling
# Cleaning data and making it ready for use to give insights through visualization and useful for training the models.
#
# We will check for:
# 1. Incomplete data ( Missing data)
# 2. Duplicated data.
# 3. Skewed data.
# 4. Outliers.
# 5. Inconsistent data ( Inconsistent format)
# 6. Imbalanced data.
#
# Find more on tidying data [here](https://youtu.be/iYie42M1ZyU)
